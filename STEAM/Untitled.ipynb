# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
filtro_rogue = r'C:\Users\danie\OneDrive\Documentos\GitHub\portfolio\STEAM\Ajuda_grupo_data_science.xlsx'
df = pd.read_excel(filtro_rogue)

# %%
df.head()
# Out:
#    App ID                  Title                                        URL  \
# 0  322330  Don't Starve Together  https://store.steampowered.com/app/322330
# 1  219740           Don't Starve  https://store.steampowered.com/app/219740
# 2  262060       Darkest Dungeon®  https://store.steampowered.com/app/262060
# 3  646570         Slay the Spire  https://store.steampowered.com/app/646570
# 4  588650             Dead Cells  https://store.steampowered.com/app/588650
#
#             Publisher  US Price  Year Released  Review Count  \
# 0  Klei Entertainment     14.99       2016.307         79104
# 1  Klei Entertainment     24.90          0.000         52167
# 2    Red Hook Studios     24.99       2016.052         47592
# 3     Mega Crit Games     24.99       2019.063         32274
# 4         Motion Twin     24.99       2018.597         27865
#
#    User Review Score                                               Tags  \
# 0                 90  Survival, Multiplayer, Co-op, Open World, Adve...
# 1                 91  Survival, Crafting, Indie, Adventure, Sandbox,...
# 2                 90  Turn-Based Combat, Dark Fantasy, Dungeon Crawl...
# 3                 92  Card Game, Rogue-like, Turn-Based, Strategy, S...
# 4                 96  Rogue-like, Metroidvania, Pixel Graphics, 2D, ...
#
#                                               Genres  \
# 0  Adventure, Indie, Simulation, Klei Entertainme...
# 1  Adventure, Indie, Simulation, Klei Entertainme...
# 2  Indie, RPG, Strategy, Red Hook Studios, Red Ho...
# 3                                    Indie, Strategy
# 4            Action, Indie, Motion Twin, Motion Twin
#
#    Estimated Revenue (net post platform)  \
# 0                               22529610
# 1                               24680210
# 2                               22597160
# 3                               15324020
# 4                               13230580
#
#    Projected Lifetime Revenue (net post platform)
# 0                                        24692400
# 1                                        24479250
# 2                                        24120450
# 3                                        22649120
# 4                                        18253460

# %%
df.drop(['URL','Publisher'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    App ID                  Title  US Price  Year Released  Review Count  \
# 0  322330  Don't Starve Together     14.99       2016.307         79104
# 1  219740           Don't Starve     24.90          0.000         52167
# 2  262060       Darkest Dungeon®     24.99       2016.052         47592
# 3  646570         Slay the Spire     24.99       2019.063         32274
# 4  588650             Dead Cells     24.99       2018.597         27865
#
#    User Review Score                                               Tags  \
# 0                 90  Survival, Multiplayer, Co-op, Open World, Adve...
# 1                 91  Survival, Crafting, Indie, Adventure, Sandbox,...
# 2                 90  Turn-Based Combat, Dark Fantasy, Dungeon Crawl...
# 3                 92  Card Game, Rogue-like, Turn-Based, Strategy, S...
# 4                 96  Rogue-like, Metroidvania, Pixel Graphics, 2D, ...
#
#                                               Genres  \
# 0  Adventure, Indie, Simulation, Klei Entertainme...
# 1  Adventure, Indie, Simulation, Klei Entertainme...
# 2  Indie, RPG, Strategy, Red Hook Studios, Red Ho...
# 3                                    Indie, Strategy
# 4            Action, Indie, Motion Twin, Motion Twin
#
#    Estimated Revenue (net post platform)  \
# 0                               22529610
# 1                               24680210
# 2                               22597160
# 3                               15324020
# 4                               13230580
#
#    Projected Lifetime Revenue (net post platform)
# 0                                        24692400
# 1                                        24479250
# 2                                        24120450
# 3                                        22649120
# 4                                        18253460
