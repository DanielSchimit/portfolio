# %%
import numpy as np
import pandas as pd
import csv
import statistics
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1# Analise de Jogos de corrida usando Steam Spy. Realizamos a extração dos dados via código com api steam, definida tag 'racing'.

# %%
df_corrida = pd.read_csv(r'C:\Users\danie\OneDrive\Documentos\GitHub\portfolio\STEAM\Jogo de corrida\20220714_steamspy_page_tag_racing0.csv')

# %%
df_corrida.head()
# Out:
#       _key    appid                    name              developer  \
# 0   271590   271590      Grand Theft Auto V         Rockstar North
# 1   227300   227300  Euro Truck Simulator 2           SCS Software
# 2   252950   252950           Rocket League            Psyonix LLC
# 3   431960   431960        Wallpaper Engine  Wallpaper Engine Team
# 4  1293830  1293830         Forza Horizon 4       Playground Games
#
#                publisher       soma positive negative  userscore  \
# 0         Rockstar Games  1375163.0  1165487   209676        0.0
# 1           SCS Software   560459.0   545408    15051        0.0
# 2            Psyonix LLC   554966.0   492663    62303        0.0
# 3  Wallpaper Engine Team   528289.0   517992    10297        0.0
# 4      Xbox Game Studios   136622.0   121590    15032        0.0
#
#                      owners  ... average_2weeks median_forever median_2weeks  \
# 0  20,000,000 .. 50,000,000  ...            666           5905           175
# ...

# %% [markdown]
# 2# Análise de vendas para um jogo de corrida.
