# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
filtro_rogue = r'C:\Users\danie\OneDrive\Documentos\GitHub\portfolio\STEAM\Ajuda_grupo_data_science.xlsx'
df = pd.read_excel(filtro_rogue)

# %%
df.head()
# Out:
#    App ID                  Title                                        URL  \
# 0    3451         High dimension                                        NaN
# 1  322330  Don't Starve Together  https://store.steampowered.com/app/322330
# 2  219740           Don't Starve  https://store.steampowered.com/app/219740
# 3  262060       Darkest Dungeon®  https://store.steampowered.com/app/262060
# 4  646570         Slay the Spire  https://store.steampowered.com/app/646570
#
#             Publisher  US Price  Year Released  Review Count  \
# 0              daniel      4.99       2023.000             0
# 1  Klei Entertainment     14.99       2016.307         79104
# 2  Klei Entertainment     24.90          0.000         52167
# 3    Red Hook Studios     24.99       2016.052         47592
# 4     Mega Crit Games     24.99       2019.063         32274
#
#    User Review Score                                               Tags  \
# ...

# %%
df.drop(['URL','Publisher'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    App ID                  Title  US Price  Year Released  Review Count  \
# 0    3451         High dimension      4.99       2023.000             0
# 1  322330  Don't Starve Together     14.99       2016.307         79104
# 2  219740           Don't Starve     24.90          0.000         52167
# 3  262060       Darkest Dungeon®     24.99       2016.052         47592
# 4  646570         Slay the Spire     24.99       2019.063         32274
#
#    User Review Score                                               Tags  \
# 0                  0  Roguelite, Action Roguelike, \n2D Platformer, ...
# 1                 90  Survival, Multiplayer, Co-op, Open World, Adve...
# 2                 91  Survival, Crafting, Indie, Adventure, Sandbox,...
# 3                 90  Turn-Based Combat, Dark Fantasy, Dungeon Crawl...
# 4                 92  Card Game, Rogue-like, Turn-Based, Strategy, S...
#
#                                               Genres  \
# ...

# %%
df['Tags'].str.split(',')
# Out:
# 0      [Roguelite,  Action Roguelike,  \n2D Platforme...
# 1      [Survival,  Multiplayer,  Co-op,  Open World, ...
# 2      [Survival,  Crafting,  Indie,  Adventure,  San...
# 3      [Turn-Based Combat,  Dark Fantasy,  Dungeon Cr...
# 4      [Card Game,  Rogue-like,  Turn-Based,  Strateg...
#                              ...
# 910    [Indie,  Rogue-lite,  Bullet Hell,  Shoot 'Em ...
# 911    [Indie,  Action,  RPG,  Gore,  Violent,  Horro...
# 912    [Indie,  Action,  Rogue-lite,  Twin Stick Shoo...
# 913    [Indie,  Action,  Space,  Shooter,  Top-Down, ...
# 914    [Indie,  Action,  Adventure,  Gore,  Arcade,  ...
# Name: Tags, Length: 915, dtype: object

# %%
df.sort_values(by=['Projected Lifetime Revenue (net post platform)', 'Tags'], axis=0, ascending=False)
# Out:
#      App ID                  Title  US Price  Year Released  Review Count  \
# 1    322330  Don't Starve Together     14.99       2016.307         79104
# 2    219740           Don't Starve     24.90          0.000         52167
# 3    262060       Darkest Dungeon®     24.99       2016.052         47592
# 4    646570         Slay the Spire     24.99       2019.063         32274
# 5    588650             Dead Cells     24.99       2018.597         27865
# ..      ...                    ...       ...            ...           ...
# 888  856050      Conjury of Nature     24.90       2018.378             0
# 885  778270       Tombo Breaker VR      9.99       2018.159             0
# 896  965880        Whimsical Quest      5.90       2018.923             0
# 890  761570        Beard &amp; Axe     19.90       2018.529             0
# 0      3451         High dimension      4.99       2023.000             0
#
#      User Review Score                                               Tags  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15840/2531771824.py in <module>
# ----> 1 df.count['Tags']
#
# TypeError: 'method' object is not subscriptable
